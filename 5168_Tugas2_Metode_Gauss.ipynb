# %% [markdown]
# <a href="https://colab.research.google.com/github/wisnalaa/Numerik/blob/main/5168_Tugas2_Metode_Gauss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Wisnala Aryawiduta
#
# NIM: 22.11.5168
#
# Kelas: IF10
#
# https://colab.research.google.com/drive/1nHFk9KGYRyxpMkhz8HxkOot4ggR2zbw1?usp=sharing

# %%
# Import NumPy Library
import numpy as np
import sys

# %%
# Memasukkan ukuran matriks
n = int(input('Masukkan ukuran matriks: '))

# Making numpy array of n x n+1 size and initializing
# to zero for storing augmented matrix
a = np.zeros((n,n+1))

# Making numpy array of n size and initializing
# to zero for storing solution vector
x = np.zeros(n)
# Out:
# Masukkan ukuran matriks: 3

# %%
#Memasukkan persamaan linier matriks. Pertanyaan nomor 1a
print('Tekan enter untuk memasukkan matriks dari persamaan linear:')
for i in range(n):
    for j in range(n+1):
        a[i][j] = float(input( 'a['+str(i)+']['+ str(j)+']='))

#Mengecek nilai 0 pada matriks. Pertanyaan Nomor 1b
for i in range(n):
    if a[i][i] == 0.0:
        sys.exit('Divide by zero detected!')

    for j in range(i+1, n):
        ratio = a[j][i]/a[i][i]

        for k in range(n+1):
            a[j][k] = a[j][k] - ratio * a[i][k]

#Menjalankan subtitusi. Pertanyaan Nomor 1c
x[n-1] = a[n-1][n]/a[n-1][n-1]

for i in range(n-2,-1,-1):
    x[i] = a[i][n]

    for j in range(i+1,n):
        x[i] = x[i] - a[i][j]*x[j]

    x[i] = x[i]/a[i][i]

#Menampilkan hasil dari perhitungan gauss. Pertanyaan Nomor 1d
print('\nAkar dari persamaan linear diatas dengan metode Gauss, adalah : ')
for i in range(n):
    print('X%d = %0.2f' %(i+1,x[i]), end = '\t')
# Out:
# Tekan enter untuk memasukkan matriks dari persamaan linear:
# a[0][0]=1
# a[0][1]=1
# a[0][2]=1
# a[0][3]=200
# a[1][0]=1
# a[1][1]=0
# a[1][2]=-1
# a[1][3]=-30
# a[2][0]=1
# a[2][1]=1
# a[2][2]=0
# a[2][3]=98
#
# Akar dari persamaan linear diatas dengan metode Gauss, adalah :
# X1 = 72.00	X2 = 26.00	X3 = 102.00

# %% [markdown]
# ![Screenshot 2024-10-02 102723.png](data:image/png;base64,...)

# %%
#Memasukkan persamaan linier matriks. Pertanyaan nomor 1a
print('Tekan enter untuk memasukkan matriks dari persamaan linear:')
for i in range(n):
    for j in range(n+1):
        a[i][j] = float(input( 'a['+str(i)+']['+ str(j)+']='))

#Mengecek nilai 0 pada matriks. Pertanyaan Nomor 1b
for i in range(n):
    if a[i][i] == 0.0:
        sys.exit('Divide by zero detected!')

    for j in range(i+1, n):
        ratio = a[j][i]/a[i][i]

        for k in range(n+1):
            a[j][k] = a[j][k] - ratio * a[i][k]

#Menjalankan subtitusi. Pertanyaan Nomor 1c
x[n-1] = a[n-1][n]/a[n-1][n-1]

for i in range(n-2,-1,-1):
    x[i] = a[i][n]

    for j in range(i+1,n):
        x[i] = x[i] - a[i][j]*x[j]

    x[i] = x[i]/a[i][i]

#Menampilkan hasil dari perhitungan gauss. Pertanyaan Nomor 1d
print('\nAkar dari persamaan linear diatas dengan metode Gauss, adalah : ')
for i in range(n):
    print('X%d = %0.2f' %(i+1,x[i]), end = '\t')
# Out:
# Tekan enter untuk memasukkan matriks dari persamaan linear:
# a[0][0]=2
# a[0][1]=3
# a[0][2]=1
# a[0][3]=17
# a[1][0]=-2
# a[1][1]=0
# a[1][2]=-3
# a[1][3]=-9
# a[2][0]=-1
# a[2][1]=2
# a[2][2]=0
# a[2][3]=6.5
#
# Akar dari persamaan linear diatas dengan metode Gauss, adalah :
# X1 = 1.50	X2 = 4.00	X3 = 2.00
